# %% [markdown]
# # Caleb Wilson I513 Homework 4

# %% [markdown]
# Import needed modules

# %%
import pandas as pd, numpy as np, os

# %% [markdown]
# Get the file. I am currently working on a windows machine so I created a windows filename with "\" slashes.
# However mac machines have the "/" slash in their path. So I created a mac filename variable to replace the windows filename with on a mac machine.

# %%
path = os.getcwd()
windows_filename = path + "\BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.csv"
mac_filename = path + "/BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.csv"

# %% [markdown]
# Create a data frame for the file.

# %%
df = pd.read_csv(windows_filename)
df.head()
# Out:
#             Timestamp  \
# 0  10/24/2016 5:09:23
# 1  10/24/2016 5:09:55
# 2  10/24/2016 5:13:07
# 3  10/24/2016 5:14:17
# 4  10/24/2016 5:14:25
#
#   Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                 No               Male
# 1                                                 No               Male
# 2                                                 No             Female
# 3                                                 No               Male
# 4                                                Yes               Male
#
#   How old are you? Which country do you live in?  \
# 0               22                        Canada
# 1               45                           usa
# 2               48                            US
# 3               57                           usa
# 4               42                           USA
#
#   Which state, province, county do you live in?  [100 Grand Bar]  \
# ...

# %% [markdown]
# Rename some of the lengthy column names for conciseness

# %%
df = df.rename(columns={'Are you going actually going trick or treating yourself?':"Trick or treat?",'Your gender:':'Gender','How old are you?':"Age","Which country do you live in?":"Country","Which state, province, county do you live in?":"State, Provenance, County",' [Any full-sized candy bar]' : 'candy_rating'},errors="raise")

# %%
df.head()
# Out:
#             Timestamp Trick or treat?  Gender Age Country  \
# 0  10/24/2016 5:09:23              No    Male  22  Canada
# 1  10/24/2016 5:09:55              No    Male  45     usa
# 2  10/24/2016 5:13:07              No  Female  48      US
# 3  10/24/2016 5:14:17              No    Male  57     usa
# 4  10/24/2016 5:14:25             Yes    Male  42     USA
#
#   State, Provenance, County  [100 Grand Bar]  \
# 0                   Ontario              JOY
# 1                        il              MEH
# 2                  Colorado              JOY
# 3                        il              JOY
# 4              South Dakota              MEH
#
#    [Anonymous brown globs that come in black and orange wrappers]  \
# 0                                            DESPAIR
# 1                                                MEH
# 2                                            DESPAIR
# 3                                                MEH
# 4                                            DESPAIR
#
# ...

# %% [markdown]
# Replace the USA/United States of America/uSA etc.. values in the country column with a standard notation

# %%
values =['US','us','Us','USa','Usa','USA! USA! USA!',"USA (I think but it's an election year so who can really tell)",'USA USA USA','the best one - usa','United States of America','United States','united states','us','usa','usA','U.S.A','U.S.','USA!','America','Units States','The Yoo Ess of Aaayyyyyy','U.S.A.','United States','u.s.','United states','United States ','United States of America ','united states ','USA! USA!','U.s.','america','USA USA USA USA','united states of america','UNited States','United Stetes','United  States of America','Trumpistan','America ','Murica','47','54','44','Merica','30']

# %%
df['Country'] = df['Country'].replace(to_replace=values,value='USA')

# %%
df.head()
# Out:
#             Timestamp Trick or treat?  Gender Age Country  \
# 0  10/24/2016 5:09:23              No    Male  22  Canada
# 1  10/24/2016 5:09:55              No    Male  45     USA
# 2  10/24/2016 5:13:07              No  Female  48     USA
# 3  10/24/2016 5:14:17              No    Male  57     USA
# 4  10/24/2016 5:14:25             Yes    Male  42     USA
#
#   State, Provenance, County  [100 Grand Bar]  \
# 0                   Ontario              JOY
# 1                        il              MEH
# 2                  Colorado              JOY
# 3                        il              JOY
# 4              South Dakota              MEH
#
#    [Anonymous brown globs that come in black and orange wrappers]  \
# 0                                            DESPAIR
# 1                                                MEH
# 2                                            DESPAIR
# 3                                                MEH
# 4                                            DESPAIR
#
# ...

# %%
print(df.shape)
# Out:
# (1259, 123)

# %% [markdown]
# Fill nan's with the ffill  method

# %%
df.fillna(method='ffill')
# Out:
#                 Timestamp Trick or treat?  Gender Age Country  \
# 0      10/24/2016 5:09:23              No    Male  22  Canada
# 1      10/24/2016 5:09:55              No    Male  45     USA
# 2      10/24/2016 5:13:07              No  Female  48     USA
# 3      10/24/2016 5:14:17              No    Male  57     USA
# 4      10/24/2016 5:14:25             Yes    Male  42     USA
# ...                   ...             ...     ...  ..     ...
# 1254  10/29/2016 16:53:53              No  Female  52     USA
# 1255   10/30/2016 6:53:55              No    Male  33     USA
# 1256  10/30/2016 11:06:11              No    Male  33     USA
# 1257  10/30/2016 16:07:27              No    Male  48  canada
# 1258  10/30/2016 17:06:46             Yes  Female  44     USA
#
#      State, Provenance, County  [100 Grand Bar]  \
# 0                      Ontario              JOY
# 1                           il              MEH
# 2                     Colorado              JOY
# ...

# %% [markdown]
# This keeps only rows with less than 10 empty columns

# %%
df = df[df.isnull().sum(axis=1) < 10]

# %%
df.head()
# Out:
#             Timestamp Trick or treat?  Gender Age Country  \
# 0  10/24/2016 5:09:23              No    Male  22  Canada
# 1  10/24/2016 5:09:55              No    Male  45     USA
# 2  10/24/2016 5:13:07              No  Female  48     USA
# 3  10/24/2016 5:14:17              No    Male  57     USA
# 4  10/24/2016 5:14:25             Yes    Male  42     USA
#
#   State, Provenance, County  [100 Grand Bar]  \
# 0                   Ontario              JOY
# 1                        il              MEH
# 2                  Colorado              JOY
# 3                        il              JOY
# 4              South Dakota              MEH
#
#    [Anonymous brown globs that come in black and orange wrappers]  \
# 0                                            DESPAIR
# 1                                                MEH
# 2                                            DESPAIR
# 3                                                MEH
# 4                                            DESPAIR
#
# ...

# %%
df.shape
# Out:
# (943, 123)

# %% [markdown]
# this commented out code creates a list that stores all of the candy columns

# %%
#column_names = []
#for col in df.columns[6:123]:
    #column_names.append(col)

# %% [markdown]
# the commented out code below deletes candy columns if more than half of the rows are empty
#
# the uncommented out code only keeps columns if they have less than half of the length of the data frame empty

# %%
#for col in column_names:
    #if (pd.isnull(df[col].values)).sum()>(len(df)/2):
        #del df[col]
        #print('deleted')
        
df = df.loc[:,df.isnull().sum(axis=0) < (len(df)/2)]

# %%
df.head()
# Out:
#             Timestamp Trick or treat?  Gender Age Country  \
# 0  10/24/2016 5:09:23              No    Male  22  Canada
# 1  10/24/2016 5:09:55              No    Male  45     USA
# 2  10/24/2016 5:13:07              No  Female  48     USA
# 3  10/24/2016 5:14:17              No    Male  57     USA
# 4  10/24/2016 5:14:25             Yes    Male  42     USA
#
#   State, Provenance, County  [100 Grand Bar]  \
# 0                   Ontario              JOY
# 1                        il              MEH
# 2                  Colorado              JOY
# 3                        il              JOY
# 4              South Dakota              MEH
#
#    [Anonymous brown globs that come in black and orange wrappers]  \
# 0                                            DESPAIR
# 1                                                MEH
# 2                                            DESPAIR
# 3                                                MEH
# 4                                            DESPAIR
#
# ...

# %%
df.to_csv('hw4_cleaned_data.csv')
